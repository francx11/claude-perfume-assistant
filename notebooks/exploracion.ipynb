# %% [markdown]
# # Exploración del Catálogo de Perfumes
#
# DÍA 3: Usa este notebook para explorar los datos antes de implementar el DataLoader.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# TODO DÍA 3: Cargar el CSV de Fragrantica
# df = pd.read_csv('../data/raw/fragrantica.csv')

# %% [markdown]
# ## Exploración Básica
#
# TODO DÍA 3:
# 1. Ver las primeras filas: df.head()
# 2. Ver info del DataFrame: df.info()
# 3. Ver estadísticas: df.describe()
# 4. Ver columnas: df.columns

# %%
# TODO: Exploración básica aquí

# %% [markdown]
# ## Limpieza de Datos
#
# TODO DÍA 3:
# 1. Verificar valores nulos: df.isnull().sum()
# 2. Verificar duplicados: df.duplicated().sum()
# 3. Explorar valores únicos en columnas categóricas

# %%
# TODO: Limpieza de datos aquí

# %% [markdown]
# ## Análisis de Notas
#
# TODO DÍA 3:
# 1. ¿Cuáles son las notas más comunes?
# 2. ¿Cómo están distribuidas las notas?
# 3. Crear visualizaciones

# %%
# TODO: Análisis de notas aquí

# %% [markdown]
# ## Análisis de Marcas
#
# TODO DÍA 3:
# 1. ¿Cuántas marcas hay?
# 2. ¿Cuáles son las marcas más populares?
# 3. Distribución de perfumes por marca

# %%
# TODO: Análisis de marcas aquí
